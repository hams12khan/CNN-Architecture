# %%
import tensorflow as tf
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # VGG -16

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,ReLU,Softmax,BatchNormalization,Flatten,Dropout

# %%
model=Sequential()


model.add(Conv2D(filters=64, kernel_size=(3,3),
                 activation='relu',input_shape=(224,224,3)))
model.add(BatchNormalization())
model.add(Conv2D(filters=64,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


model.add(Conv2D(filters=128,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=128,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


model.add(Conv2D(filters=256,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=256,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=256,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


model.add(Conv2D(filters=512,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=512,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=512,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


model.add(Flatten())

model.add(Dense(units=4096,activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(units=4096,activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(units=1000,activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer=tf.optimizers.SGD(lr=0.001), 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 222, 222, 64)      1792
#
#  batch_normalization_11 (Bat  (None, 222, 222, 64)     256
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 220, 220, 64)      36928
#
#  batch_normalization_12 (Bat  (None, 220, 220, 64)     256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 110, 110, 64)     0
#  2D)
#
#  conv2d_18 (Conv2D)          (None, 108, 108, 128)     73856
#
#  batch_normalization_13 (Bat  (None, 108, 108, 128)    512
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 106, 106, 128)     147584
#
#  batch_normalization_14 (Bat  (None, 106, 106, 128)    512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 53, 53, 128)      0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 51, 51, 256)       295168
#
#  batch_normalization_15 (Bat  (None, 51, 51, 256)      1024
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 49, 49, 256)       590080
#
#  batch_normalization_16 (Bat  (None, 49, 49, 256)      1024
#  chNormalization)
#
#  conv2d_22 (Conv2D)          (None, 47, 47, 256)       590080
#
#  batch_normalization_17 (Bat  (None, 47, 47, 256)      1024
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 23, 23, 256)      0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 21, 21, 512)       1180160
#
#  batch_normalization_18 (Bat  (None, 21, 21, 512)      2048
#  chNormalization)
#
#  conv2d_24 (Conv2D)          (None, 19, 19, 512)       2359808
#
#  batch_normalization_19 (Bat  (None, 19, 19, 512)      2048
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 17, 17, 512)       2359808
#
#  batch_normalization_20 (Bat  (None, 17, 17, 512)      2048
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 512)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 4096)              134221824
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_2 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 1000)              4097000
#
# =================================================================
# Total params: 162,746,152
# Trainable params: 162,740,776
# Non-trainable params: 5,376
# _________________________________________________________________
# C:\Users\hhaha\AppData\Roaming\Python\Python39\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
import visualkeras 
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=3299x1184>
